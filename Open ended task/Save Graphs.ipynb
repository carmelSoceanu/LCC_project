# %%
import Utils
import Results
import Graphs

# %%
datasets = Utils.get_datasets()
results = Results.load_results()

# %%
Graphs.plot_all_regressions_separated(datasets, results)

# %%
Graphs.plot_dataset_comparison(datasets, results, filename='Graphs/Comparisons.png')

# %%
dataset_name = 'Mitchell'
participant_idx = 0

Graphs.plot_testing_losses(results, dataset_name, datasets[dataset_name]['participants'][participant_idx], filename='Graphs/Losses.png')
