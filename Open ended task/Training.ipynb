# %%
import Train
import time

# %%
start = time.time()
# Train all models on all datasets
Train.train_models()

end = time.time()
total_time = end - start
minutes, seconds = divmod(total_time, 60)
print(f'Total time: {int(minutes)} minutes and {seconds:.1f} seconds.')
# Out:
#   DATASET     PARTICIPANT   CONCEPTS     MODEL      VS    BASELINE    <=>   MODEL_MSE    VS  BASELINE_MSE  ~   P-VALUE       ALPHA    SIGNIFICANT
# ******************************************************************************************************************************************************
#   Mitchell         P1          60         bert      VS   random_768   <=>   5.221e-03    VS   2.970e-01    ~  8.357e-12    1.111e-03       1
#   Mitchell         P1          60       roberta     VS   random_768   <=>   3.173e-03    VS   2.852e-01    ~  8.357e-12    1.111e-03       1
#   Mitchell         P1          60      distilbert   VS   random_768   <=>   3.927e-03    VS   3.287e-01    ~  8.357e-12    1.111e-03       1
#   Mitchell         P1          60        xlnet      VS   random_768   <=>   4.763e-03    VS   2.840e-01    ~  8.357e-12    1.111e-03       1
# ...
